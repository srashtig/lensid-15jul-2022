# %%
from strong_lensing_ml.ML_utils import *

# %% [markdown]
# # ML QTs

# %%
tag=''#'_kaggle'
xgb_qts = joblib.load('../../saved_models/XGBQT_0.pkl')
    #'../../training_cv/out/XGBQT_0'+tag+'.pkl'#'../../../saved_models/XGBQT_0.pkl')

# %%
O3a_real_df_qts = pd.read_csv('../../data/dataframes/O3a_events/filtered_mass_pairs_QTs'+tag+'.csv',index_col=0)

# %%
O3a_real_df_qts.tail()
# Out:
#                   img_0               img_1  Lensing  dense_H1_0  \
# 625  GW190915_235702-v1  GW190929_012149-v1      NaN    0.600532
# 626  GW190915_235702-v1  GW190930_133541-v1      NaN    0.813278
# 627  GW190924_021846-v1  GW190929_012149-v1      NaN    0.560249
# 628  GW190924_021846-v1  GW190930_133541-v1      NaN    0.882506
# 629  GW190929_012149-v1  GW190930_133541-v1      NaN    0.016543
#
#      mean_overlap_qts_H1  std_overlap_qts_H1  lsq_overlap_qts_H1  dense_L1_0  \
# 625          6716.979492            0.101729           4854.1380    0.995177
# 626          7018.240234            0.106021           6224.9920    0.054479
# 627          7481.052246            0.109629           4934.6720    0.069947
# 628          7927.925293            0.113686           5385.7160    0.051212
# 629          8052.029297            0.117351           5257.5493    0.461666
#
#      mean_overlap_qts_L1  std_overlap_qts_L1  lsq_overlap_qts_L1  dense_V1_0  \
# 625          6734.751953            0.104256           3852.5020    0.851531
# 626          7198.800781            0.107604           4863.6484         NaN
# 627          7169.448242            0.106692           5101.3755    0.850803
# 628          7889.203613            0.115266           4693.3440         NaN
# 629          7185.698242            0.106337           4975.0750         NaN
#
#      mean_overlap_qts_V1  std_overlap_qts_V1  lsq_overlap_qts_V1
# 625          8351.734375            0.116792           3875.1768
# 626             0.000000            0.000000          18825.9600
# 627          8377.916016            0.115959           5026.3647
# 628             0.000000            0.000000          19230.2870
# 629             0.000000            0.000000          19127.9220

# %%
O3a_real_df_qts=predict_xgboost_dense_qts(O3a_real_df_qts,xgb_qts)
O3a_real_df_qts.tail()
# Out:
#                   img_0               img_1  Lensing  dense_H1_0  \
# 625  GW190915_235702-v1  GW190929_012149-v1      NaN    0.600532
# 626  GW190915_235702-v1  GW190930_133541-v1      NaN    0.813278
# 627  GW190924_021846-v1  GW190929_012149-v1      NaN    0.560249
# 628  GW190924_021846-v1  GW190930_133541-v1      NaN    0.882506
# 629  GW190929_012149-v1  GW190930_133541-v1      NaN    0.016543
#
#      mean_overlap_qts_H1  std_overlap_qts_H1  lsq_overlap_qts_H1  dense_L1_0  \
# 625          6716.979492            0.101729           4854.1380    0.995177
# 626          7018.240234            0.106021           6224.9920    0.054479
# 627          7481.052246            0.109629           4934.6720    0.069947
# 628          7927.925293            0.113686           5385.7160    0.051212
# 629          8052.029297            0.117351           5257.5493    0.461666
#
#      mean_overlap_qts_L1  std_overlap_qts_L1  lsq_overlap_qts_L1  dense_V1_0  \
# 625          6734.751953            0.104256           3852.5020    0.851531
# 626          7198.800781            0.107604           4863.6484         NaN
# 627          7169.448242            0.106692           5101.3755    0.850803
# 628          7889.203613            0.115266           4693.3440         NaN
# 629          7185.698242            0.106337           4975.0750         NaN
#
#      mean_overlap_qts_V1  std_overlap_qts_V1  lsq_overlap_qts_V1  \
# 625          8351.734375            0.116792           3875.1768
# 626             0.000000            0.000000          18825.9600
# 627          8377.916016            0.115959           5026.3647
# 628             0.000000            0.000000          19230.2870
# 629             0.000000            0.000000          19127.9220
#
#      xgb_dense_QTS_0
# 625         0.015828
# 626         0.044307
# 627         0.010614
# 628         0.045195
# 629         0.007637

# %%
O3a_real_df_qts.to_csv('../../data/dataframes/O3a_events/ML_QTs.csv')

# %% [markdown]
# # ML sky

# %%
xgb_sky = joblib.load('../../saved_models/XGBsky_0.pkl')
#'../../training_cv/out/XGBsky_0.pkl')#'../../../saved_models/XGBsky_0.pkl')

# %%
O3a_real_df_sky_bayestar = pd.read_csv('../../data/dataframes/O3a_events/filtered_mass_pairs_sky.csv',index_col=0)

# %%
O3a_real_df_sky_bayestar.tail()
# Out:
#                   img_0               img_1  Lensing  bayestar_skymaps_blu  \
# 430  GW190915_235702-v1  GW190929_012149-v1      NaN          1.669147e-03
# 431  GW190915_235702-v1  GW190930_133541-v1      NaN          4.631670e-07
# 432  GW190924_021846-v1  GW190929_012149-v1      NaN          2.896601e-07
# 433  GW190924_021846-v1  GW190930_133541-v1      NaN          2.209171e-06
# 434  GW190929_012149-v1  GW190930_133541-v1      NaN          8.150455e-01
#
#      bayestar_skymaps_d2  bayestar_skymaps_d3  bayestar_skymaps_lsq
# 430         1.345814e-05         2.685057e-04              0.173667
# 431         3.734461e-09         4.486699e-08              0.176419
# 432         2.335496e-09         3.147772e-08              0.121602
# 433         1.781229e-08         2.104884e-07              0.124069
# 434         6.571617e-03         6.266693e-02              0.130460

# %%
O3a_real_df_sky_bayestar = XGB_predict(O3a_real_df_sky_bayestar,xgb_sky)
O3a_real_df_sky_bayestar.tail()
# Out:
#                   img_0               img_1  Lensing  bayestar_skymaps_blu  \
# 430  GW190915_235702-v1  GW190929_012149-v1      NaN          1.669147e-03
# 431  GW190915_235702-v1  GW190930_133541-v1      NaN          4.631670e-07
# 432  GW190924_021846-v1  GW190929_012149-v1      NaN          2.896601e-07
# 433  GW190924_021846-v1  GW190930_133541-v1      NaN          2.209171e-06
# 434  GW190929_012149-v1  GW190930_133541-v1      NaN          8.150455e-01
#
#      bayestar_skymaps_d2  bayestar_skymaps_d3  bayestar_skymaps_lsq  \
# 430         1.345814e-05         2.685057e-04              0.173667
# 431         3.734461e-09         4.486699e-08              0.176419
# 432         2.335496e-09         3.147772e-08              0.121602
# 433         1.781229e-08         2.104884e-07              0.124069
# 434         6.571617e-03         6.266693e-02              0.130460
#
#      xgb_pred_bayestar_skymaps
# 430                   0.000004
# 431                   0.000004
# 432                   0.000007
# 433                   0.000005
# 434                   0.000096

# %%
O3a_real_df_sky_bayestar.to_csv('../../data/dataframes/O3a_events/ML_sky.csv')

# %%
O3a_real_df_sky_pe = pd.read_csv('../../data/dataframes/O3a_events/filtered_mass_pairs_PE_sky.csv',index_col=0)

# %%
O3a_real_df_sky_pe.tail()
# Out:
#                   img_0               img_1  Lensing  pe_skymaps_blu  \
# 625  GW190915_235702-v1  GW190929_012149-v1      NaN    1.669147e-03
# 626  GW190915_235702-v1  GW190930_133541-v1      NaN    4.631670e-07
# 627  GW190924_021846-v1  GW190929_012149-v1      NaN    2.896601e-07
# 628  GW190924_021846-v1  GW190930_133541-v1      NaN    2.209171e-06
# 629  GW190929_012149-v1  GW190930_133541-v1      NaN    8.150455e-01
#
#      pe_skymaps_d2  pe_skymaps_d3  pe_skymaps_lsq
# 625   1.345814e-05   2.685057e-04        0.173667
# 626   3.734461e-09   4.486699e-08        0.176419
# 627   2.335496e-09   3.147772e-08        0.121602
# 628   1.781229e-08   2.104884e-07        0.124069
# 629   6.571617e-03   6.266693e-02        0.130460

# %%
O3a_real_df_sky_pe = XGB_predict(O3a_real_df_sky_pe,xgb_sky,data_mode_xgb='pe_skymaps')
O3a_real_df_sky_pe.tail()
# Out:
#                   img_0               img_1  Lensing  pe_skymaps_blu  \
# 625  GW190915_235702-v1  GW190929_012149-v1      NaN    1.669147e-03
# 626  GW190915_235702-v1  GW190930_133541-v1      NaN    4.631670e-07
# 627  GW190924_021846-v1  GW190929_012149-v1      NaN    2.896601e-07
# 628  GW190924_021846-v1  GW190930_133541-v1      NaN    2.209171e-06
# 629  GW190929_012149-v1  GW190930_133541-v1      NaN    8.150455e-01
#
#      pe_skymaps_d2  pe_skymaps_d3  pe_skymaps_lsq  xgb_pred_pe_skymaps
# 625   1.345814e-05   2.685057e-04        0.173667             0.000004
# 626   3.734461e-09   4.486699e-08        0.176419             0.000004
# 627   2.335496e-09   3.147772e-08        0.121602             0.000007
# 628   1.781229e-08   2.104884e-07        0.124069             0.000005
# 629   6.571617e-03   6.266693e-02        0.130460             0.000096

# %%
O3a_real_df_sky_pe.to_csv('../../data/dataframes/O3a_events/ML_sky_pe.csv')

# %% [markdown]
# # combine ML results

# %%
df_sky = pd.read_csv('../../data/dataframes/O3a_events/ML_sky.csv',index_col=0)
df_sky_pe = pd.read_csv('../../data/dataframes/O3a_events/ML_sky_pe.csv',index_col=0)
df_qts = pd.read_csv('../../data/dataframes/O3a_events/ML_QTs.csv',index_col=0)

# %%
O3a_real_ml=pd.merge(df_sky, df_qts, on=["img_0", "img_1","Lensing"])
O3a_real_ml['densnet_xgbsky_bayestar_mul_0'] = O3a_real_ml['xgb_dense_QTS_0']*O3a_real_ml['xgb_pred_bayestar_skymaps']
O3a_real_ml
# Out:
#                   img_0               img_1  Lensing  bayestar_skymaps_blu  \
# 0    GW190408_181802-v1         GW190412-v3      NaN          1.391314e-02
# 1    GW190408_181802-v1  GW190413_052954-v1      NaN          1.291094e-03
# 2    GW190408_181802-v1  GW190413_134308-v1      NaN          7.343749e-01
# 3    GW190408_181802-v1  GW190421_213856-v1      NaN          2.752217e-01
# 4    GW190408_181802-v1  GW190503_185404-v1      NaN          7.939546e-10
# ..                  ...                 ...      ...                   ...
# 430  GW190915_235702-v1  GW190929_012149-v1      NaN          1.669147e-03
# 431  GW190915_235702-v1  GW190930_133541-v1      NaN          4.631670e-07
# 432  GW190924_021846-v1  GW190929_012149-v1      NaN          2.896601e-07
# 433  GW190924_021846-v1  GW190930_133541-v1      NaN          2.209171e-06
# 434  GW190929_012149-v1  GW190930_133541-v1      NaN          8.150455e-01
#
#      bayestar_skymaps_d2  bayestar_skymaps_d3  bayestar_skymaps_lsq  \
# 0           1.121800e-04         5.638905e-03              0.141688
# 1           1.040994e-05         1.797056e-04              0.173724
# 2           5.921179e-03         1.079561e-01              0.160927
# 3           2.219081e-03         4.367474e-02              0.208259
# 4           6.401564e-12         1.058589e-10              0.155704
# ..                   ...                  ...                   ...
# 430         1.345814e-05         2.685057e-04              0.173667
# 431         3.734461e-09         4.486699e-08              0.176419
# 432         2.335496e-09         3.147772e-08              0.121602
# 433         1.781229e-08         2.104884e-07              0.124069
# 434         6.571617e-03         6.266693e-02              0.130460
#
#      xgb_pred_bayestar_skymaps  dense_H1_0  mean_overlap_qts_H1  ...  \
# 0                     0.000004    0.427013          6454.494629  ...
# 1                     0.000004    0.207625          6676.333984  ...
# 2                     0.000037    0.050365          6539.323242  ...
# 3                     0.000007    0.985114          6293.993652  ...
# 4                     0.000004    0.876610          6239.953125  ...
# ..                         ...         ...                  ...  ...
# 430                   0.000004    0.600532          6716.979492  ...
# 431                   0.000004    0.813278          7018.240234  ...
# 432                   0.000007    0.560249          7481.052246  ...
# 433                   0.000005    0.882506          7927.925293  ...
# 434                   0.000096    0.016543          8052.029297  ...
#
#      dense_L1_0  mean_overlap_qts_L1  std_overlap_qts_L1  lsq_overlap_qts_L1  \
# 0      0.009407          6448.484863            0.097849           3803.8733
# 1      0.038902          6980.054688            0.103705           5026.1387
# 2      0.467969          6035.040527            0.094061           3824.9563
# 3      0.239202          6787.040039            0.102576           4212.5460
# 4      0.141227          6993.958008            0.108472           4467.5415
# ..          ...                  ...                 ...                 ...
# 430    0.995177          6734.751953            0.104256           3852.5020
# 431    0.054479          7198.800781            0.107604           4863.6484
# 432    0.069947          7169.448242            0.106692           5101.3755
# 433    0.051212          7889.203613            0.115266           4693.3440
# 434    0.461666          7185.698242            0.106337           4975.0750
#
#      dense_V1_0  mean_overlap_qts_V1  std_overlap_qts_V1  lsq_overlap_qts_V1  \
# 0      0.271809          8637.546875            0.123289           4931.5220
# 1      0.631992          8044.645020            0.117166           4720.2827
# 2      0.731556          8566.871094            0.121433           4400.6000
# 3           NaN             0.000000            0.000000          19510.3630
# 4      0.690137          8721.298828            0.118734           5254.8240
# ..          ...                  ...                 ...                 ...
# 430    0.851531          8351.734375            0.116792           3875.1768
# 431         NaN             0.000000            0.000000          18825.9600
# 432    0.850803          8377.916016            0.115959           5026.3647
# 433         NaN             0.000000            0.000000          19230.2870
# 434         NaN             0.000000            0.000000          19127.9220
#
#      xgb_dense_QTS_0  densnet_xgbsky_bayestar_mul_0
# 0           0.020485                   8.244242e-08
# 1           0.011078                   4.472054e-08
# 2           0.004644                   1.708975e-07
# 3           0.235641                   1.664213e-06
# 4           0.009820                   3.951910e-08
# ..               ...                            ...
# 430         0.015828                   6.389647e-08
# 431         0.044307                   1.596503e-07
# 432         0.010614                   7.075707e-08
# 433         0.045195                   2.116783e-07
# 434         0.007637                   7.340595e-07
#
# [435 rows x 22 columns]

# %%
O3a_real_ml.to_csv('../../data/dataframes/O3a_events/ML_combined.csv')

# %%
O3a_real_ml_pe_sky=pd.merge(df_sky_pe, df_qts, on=["img_0", "img_1","Lensing"])
O3a_real_ml_pe_sky['densnet_xgbsky_pe_mul_0'] = O3a_real_ml_pe_sky['xgb_dense_QTS_0']*O3a_real_ml_pe_sky['xgb_pred_pe_skymaps']
O3a_real_ml_pe_sky
# Out:
#                   img_0               img_1  Lensing  pe_skymaps_blu  \
# 0    GW190408_181802-v1         GW190412-v3      NaN    1.391314e-02
# 1    GW190408_181802-v1  GW190413_052954-v1      NaN    1.291094e-03
# 2    GW190408_181802-v1  GW190413_134308-v1      NaN    7.343749e-01
# 3    GW190408_181802-v1  GW190421_213856-v1      NaN    2.752217e-01
# 4    GW190408_181802-v1  GW190424_180648-v1      NaN             NaN
# ..                  ...                 ...      ...             ...
# 625  GW190915_235702-v1  GW190929_012149-v1      NaN    1.669147e-03
# 626  GW190915_235702-v1  GW190930_133541-v1      NaN    4.631670e-07
# 627  GW190924_021846-v1  GW190929_012149-v1      NaN    2.896601e-07
# 628  GW190924_021846-v1  GW190930_133541-v1      NaN    2.209171e-06
# 629  GW190929_012149-v1  GW190930_133541-v1      NaN    8.150455e-01
#
#      pe_skymaps_d2  pe_skymaps_d3  pe_skymaps_lsq  xgb_pred_pe_skymaps  \
# 0     1.121800e-04   5.638905e-03        0.141688             0.000004
# 1     1.040994e-05   1.797056e-04        0.173724             0.000004
# 2     5.921179e-03   1.079561e-01        0.160927             0.000037
# 3     2.219081e-03   4.367474e-02        0.208259             0.000007
# 4              NaN            NaN             NaN             0.000033
# ..             ...            ...             ...                  ...
# 625   1.345814e-05   2.685057e-04        0.173667             0.000004
# 626   3.734461e-09   4.486699e-08        0.176419             0.000004
# 627   2.335496e-09   3.147772e-08        0.121602             0.000007
# 628   1.781229e-08   2.104884e-07        0.124069             0.000005
# 629   6.571617e-03   6.266693e-02        0.130460             0.000096
#
#      dense_H1_0  mean_overlap_qts_H1  ...  dense_L1_0  mean_overlap_qts_L1  \
# 0      0.427013          6454.494629  ...    0.009407          6448.484863
# 1      0.207625          6676.333984  ...    0.038902          6980.054688
# 2      0.050365          6539.323242  ...    0.467969          6035.040527
# 3      0.985114          6293.993652  ...    0.239202          6787.040039
# 4           NaN             0.000000  ...    0.002744          6477.819824
# ..          ...                  ...  ...         ...                  ...
# 625    0.600532          6716.979492  ...    0.995177          6734.751953
# 626    0.813278          7018.240234  ...    0.054479          7198.800781
# 627    0.560249          7481.052246  ...    0.069947          7169.448242
# 628    0.882506          7927.925293  ...    0.051212          7889.203613
# 629    0.016543          8052.029297  ...    0.461666          7185.698242
#
#      std_overlap_qts_L1  lsq_overlap_qts_L1  dense_V1_0  mean_overlap_qts_V1  \
# 0              0.097849           3803.8733    0.271809          8637.546875
# 1              0.103705           5026.1387    0.631992          8044.645020
# 2              0.094061           3824.9563    0.731556          8566.871094
# 3              0.102576           4212.5460         NaN             0.000000
# 4              0.097575           4185.9880         NaN             0.000000
# ..                  ...                 ...         ...                  ...
# 625            0.104256           3852.5020    0.851531          8351.734375
# 626            0.107604           4863.6484         NaN             0.000000
# 627            0.106692           5101.3755    0.850803          8377.916016
# 628            0.115266           4693.3440         NaN             0.000000
# 629            0.106337           4975.0750         NaN             0.000000
#
#      std_overlap_qts_V1  lsq_overlap_qts_V1  xgb_dense_QTS_0  \
# 0              0.123289           4931.5220         0.020485
# 1              0.117166           4720.2827         0.011078
# 2              0.121433           4400.6000         0.004644
# 3              0.000000          19510.3630         0.235641
# 4              0.000000          19510.3630         0.002744
# ..                  ...                 ...              ...
# 625            0.116792           3875.1768         0.015828
# 626            0.000000          18825.9600         0.044307
# 627            0.115959           5026.3647         0.010614
# 628            0.000000          19230.2870         0.045195
# 629            0.000000          19127.9220         0.007637
#
#      densnet_xgbsky_pe_mul_0
# 0               8.244242e-08
# 1               4.472054e-08
# 2               1.708975e-07
# 3               1.664213e-06
# 4               9.002745e-08
# ..                       ...
# 625             6.389647e-08
# 626             1.596503e-07
# 627             7.075707e-08
# 628             2.116783e-07
# 629             7.340595e-07
#
# [630 rows x 22 columns]

# %%
O3a_real_ml_pe_sky.to_csv('../../data/dataframes/O3a_events/ML_combined_pe_sky.csv')

# %% [markdown]
# # Compute FPPs

# %%
tag='_git'
ML_O3a_inj_df = pd.read_csv('../../data/dataframes/O3a_psd/ML_combined'+tag+'.csv',index_col=0)

# %%
ML_predictions_O3a_real = pd.read_csv('../../data/dataframes/O3a_events/ML_combined.csv',index_col=0)

# %%
ML_predictions_O3a_real_pe_sky = pd.read_csv('../../data/dataframes/O3a_events/ML_combined_pe_sky.csv',index_col=0)

# %%
bins=np.linspace(-5,0,30)

ml_stat= 'densnet_xgbsky_bayestar_mul_0'
ML_predictions_O3a_real[ml_stat+'_fpp']=get_fars(ML_predictions_O3a_real,ml_stat,ML_O3a_inj_df,ml_stat[:-2])
plt.hist(np.log10(ML_predictions_O3a_real[ml_stat+'_fpp']),bins=bins,label='ML combined', histtype='step',density=True,lw=2,ls='dashed')

ml_stat= 'xgb_pred_bayestar_skymaps'
ML_predictions_O3a_real[ml_stat+'_fpp']=get_fars(ML_predictions_O3a_real,ml_stat,ML_O3a_inj_df,ml_stat)
plt.hist(np.log10(ML_predictions_O3a_real[ml_stat+'_fpp']),bins=bins,label='ML sky ', histtype='step',density=True,lw=2,ls='dashed')

ml_stat= 'xgb_dense_QTS_0'
ML_predictions_O3a_real[ml_stat+'_fpp']=get_fars(ML_predictions_O3a_real,ml_stat,ML_O3a_inj_df,ml_stat[:-2])
plt.hist(np.log10(ML_predictions_O3a_real[ml_stat+'_fpp']),bins=bins,label='ML qts ', histtype='step',density=True,lw=2,ls='dashed')

plt.legend()
plt.xlabel('FPP(log10)')
plt.ylabel('PDF')
plt.grid()
plt.suptitle('FPPs distribution O3a real events with ML')
plt.show()
# Out:
# /home1/srashti.goyal/anaconda3/envs/bilby_env/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:808: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home1/srashti.goyal/anaconda3/envs/bilby_env/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:808: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home1/srashti.goyal/anaconda3/envs/bilby_env/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:808: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
plt.figure(figsize=(10,7))
bins=np.linspace(-5,0,30)

ml_stat= 'densnet_xgbsky_pe_mul_0'
ML_predictions_O3a_real_pe_sky[ml_stat+'_fpp']=get_fars(ML_predictions_O3a_real_pe_sky,ml_stat,ML_O3a_inj_df,'densnet_xgbsky_bayestar_mul')
plt.hist(np.log10(ML_predictions_O3a_real_pe_sky[ml_stat+'_fpp']),bins=bins,label='ML combined', histtype='step',density=True,lw=2,ls='dashed')

ml_stat= 'xgb_pred_pe_skymaps'
ML_predictions_O3a_real_pe_sky[ml_stat+'_fpp']=get_fars(ML_predictions_O3a_real_pe_sky,ml_stat,ML_O3a_inj_df,'xgb_pred_bayestar_skymaps')
plt.hist(np.log10(ML_predictions_O3a_real_pe_sky[ml_stat+'_fpp']),bins=bins,label='ML sky ', histtype='step',density=True,lw=2,ls='dashed')

ml_stat= 'xgb_pred_bayestar_skymaps'
ML_predictions_O3a_real[ml_stat+'_fpp']=get_fars(ML_predictions_O3a_real,ml_stat,ML_O3a_inj_df,ml_stat)
plt.hist(np.log10(ML_predictions_O3a_real[ml_stat+'_fpp']),bins=bins,label='ML sky (bayestar)', histtype='step',density=True,lw=2,ls='dashed')

ml_stat= 'xgb_dense_QTS_0'
ML_predictions_O3a_real_pe_sky[ml_stat+'_fpp']=get_fars(ML_predictions_O3a_real_pe_sky,ml_stat,ML_O3a_inj_df,ml_stat[:-2])
plt.hist(np.log10(ML_predictions_O3a_real_pe_sky[ml_stat+'_fpp']),bins=bins,label='ML qts ', histtype='step',density=True,lw=2,ls='dashed')


plt.legend()
plt.xlabel('FPP(log10)')
plt.ylabel('PDF')
plt.grid()
plt.suptitle('FPPs distribution O3a real events with ML using PE skymaps')
plt.show()
# Out:
# /home1/srashti.goyal/anaconda3/envs/bilby_env/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:808: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home1/srashti.goyal/anaconda3/envs/bilby_env/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:808: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home1/srashti.goyal/anaconda3/envs/bilby_env/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:808: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# /home1/srashti.goyal/anaconda3/envs/bilby_env/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:808: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
cols = np.intersect1d(ML_predictions_O3a_real.columns.values,ML_predictions_O3a_real_pe_sky.columns.values)
ML_predictions_O3a_real_merged=pd.merge(ML_predictions_O3a_real_pe_sky, ML_predictions_O3a_real, on=list(cols))

# %%
cols
# Out:
# array(['Lensing', 'dense_H1_0', 'dense_L1_0', 'dense_V1_0', 'img_0',
#        'img_1', 'lsq_overlap_qts_H1', 'lsq_overlap_qts_L1',
#        'lsq_overlap_qts_V1', 'mean_overlap_qts_H1', 'mean_overlap_qts_L1',
#        'mean_overlap_qts_V1', 'std_overlap_qts_H1', 'std_overlap_qts_L1',
#        'std_overlap_qts_V1', 'xgb_dense_QTS_0', 'xgb_dense_QTS_0_fpp'],
#       dtype=object)

# %%
#ML_predictions_O3a_real_merged[['xgb_pred_bayestar_skymaps','xgb_pred_pe_skymaps']]

# %%
ML_predictions_O3a_real_pe_sky.to_csv('../../data/dataframes/O3a_events/ML_combined_pe_sky_FPPs.csv')
ML_predictions_O3a_real.to_csv('../../data/dataframes/O3a_events/ML_combined_FPPs.csv')
ML_predictions_O3a_real_merged.to_csv('../../data/dataframes/O3a_events/ML_combined_merged_FPPs.csv')

# %%
ML_predictions_O3a_real_merged.tail()
# Out:
#                   img_0               img_1  Lensing  pe_skymaps_blu  \
# 430  GW190915_235702-v1  GW190929_012149-v1      NaN    1.669147e-03
# 431  GW190915_235702-v1  GW190930_133541-v1      NaN    4.631670e-07
# 432  GW190924_021846-v1  GW190929_012149-v1      NaN    2.896601e-07
# 433  GW190924_021846-v1  GW190930_133541-v1      NaN    2.209171e-06
# 434  GW190929_012149-v1  GW190930_133541-v1      NaN    8.150455e-01
#
#      pe_skymaps_d2  pe_skymaps_d3  pe_skymaps_lsq  xgb_pred_pe_skymaps  \
# 430   1.345814e-05   2.685057e-04        0.173667             0.000004
# 431   3.734461e-09   4.486699e-08        0.176419             0.000004
# 432   2.335496e-09   3.147772e-08        0.121602             0.000007
# 433   1.781229e-08   2.104884e-07        0.124069             0.000005
# 434   6.571617e-03   6.266693e-02        0.130460             0.000096
#
#      dense_H1_0  mean_overlap_qts_H1  ...  xgb_pred_pe_skymaps_fpp  \
# 430    0.600532          6716.979492  ...                 0.834128
# 431    0.813278          7018.240234  ...                 0.915680
# 432    0.560249          7481.052246  ...                 0.570342
# 433    0.882506          7927.925293  ...                 0.772561
# 434    0.016543          8052.029297  ...                 0.143331
#
#      xgb_dense_QTS_0_fpp  bayestar_skymaps_blu  bayestar_skymaps_d2  \
# 430             0.293683          1.669147e-03         1.345814e-05
# 431             0.084080          4.631670e-07         3.734461e-09
# 432             0.459159          2.896601e-07         2.335496e-09
# 433             0.082200          2.209171e-06         1.781229e-08
# 434             0.603425          8.150455e-01         6.571617e-03
#
#      bayestar_skymaps_d3  bayestar_skymaps_lsq  xgb_pred_bayestar_skymaps  \
# 430         2.685057e-04              0.173667                   0.000004
# 431         4.486699e-08              0.176419                   0.000004
# 432         3.147772e-08              0.121602                   0.000007
# 433         2.104884e-07              0.124069                   0.000005
# 434         6.266693e-02              0.130460                   0.000096
#
#      densnet_xgbsky_bayestar_mul_0  densnet_xgbsky_bayestar_mul_0_fpp  \
# 430                   6.389647e-08                           0.585968
# 431                   1.596503e-07                           0.386918
# 432                   7.075707e-08                           0.560643
# 433                   2.116783e-07                           0.339488
# 434                   7.340595e-07                           0.185160
#
#      xgb_pred_bayestar_skymaps_fpp
# 430                       0.834128
# 431                       0.915680
# 432                       0.570342
# 433                       0.772561
# 434                       0.143331
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Compare with BLU

# %%
blu_haris_O3a_real = pd.read_csv('../../data/O3a_events/O3a_blu.txt',delimiter='\t')
blu_haris_O3a_inj = pd.read_csv('../../data/dataframes/O3a_haris/blu_injections.csv')
blu_haris_O3a_inj['Lensing']=0
blu_haris_O3a_real['blu_fpp'] = get_fars(blu_haris_O3a_real,'blu',blu_haris_O3a_inj,'blu',plot=False,logy=True)
# Out:
# /home1/srashti.goyal/anaconda3/envs/bilby_env/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:808: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
blu_haris_O3a_real.tail()
# Out:
#               event1           event2            blu  rlu_haris  \
# 698  GW190930_133541  GW190828_065509  8.200000e-108     0.0704
# 699  GW190930_133541  GW190909_114149   6.460000e-82     0.1450
# 700  GW190930_133541  GW190910_112807   0.000000e+00     0.1560
# 701  GW190930_133541  GW190924_021846   0.000000e+00     0.6460
# 702  GW190930_133541  GW190929_012149   0.000000e+00     3.0200
#
#      rlu_anupreeta   blu_fpp
# 698          0.461  0.250133
# 699          1.090  0.237155
# 700          1.190  1.000000
# 701          4.460  1.000000
# 702          9.520  1.000000

# %%
plt.plot(blu_haris_O3a_real['blu'],blu_haris_O3a_real['blu_fpp'],'.')
plt.axvline(50,color='k',ls='dashed',label='$B^L_U$ = 50')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$B^L_U$')
plt.ylabel('FAR')
plt.legend()
plt.xlim(1,1e5)
plt.grid()
plt.show()

# %%
ML_O3a_real=pd.read_csv('../../data/dataframes/O3a_events/ML_combined_pe_sky_FPPs.csv',index_col=0)
#ML_O3a_real=pd.read_csv('../../data/dataframes/O3a_events/ML_combined_merged_FPPs.csv',index_col=0)

# %%
ml_stat = 'densnet_xgbsky_pe_mul_0'
blu_stat='blu'
bins=10.**np.linspace(-3,0,20)
plt.hist(ML_O3a_real[ml_stat+'_fpp'],cumulative=1,bins=bins,histtype='step',label='ML',lw=2)
plt.hist(blu_haris_O3a_real[blu_stat+'_fpp'],cumulative=1,bins=bins,histtype='step',label='$B^L_U$',lw=2)
plt.legend()
plt.xscale('log')
#plt.yscale('log')
plt.xlabel('FPP')
plt.ylabel('cumulative no. of pairs')
plt.grid()
plt.show()

# %%
blu_haris_O3a_real[blu_haris_O3a_real[blu_stat+'_fpp']<1e-2].reset_index()
# Out:
#     index           event1           event2            blu  rlu_haris  \
# 0      57  GW190413_134308  GW190512_180714  1.490000e-316     0.0865
# 1      69  GW190421_213856  GW190910_112807   9.550000e+01     0.0110
# 2      72  GW190424_180648  GW190413_052954   1.390000e+02     0.3290
# 3      79  GW190424_180648  GW190521_074359   5.090000e+01     0.1000
# 4      85  GW190424_180648  GW190803_022701   5.660000e+01     0.0123
# 5      89  GW190424_180648  GW190910_112807   1.300000e+02     0.0108
# 6     249  GW190527_092055  GW190719_215514   4.810000e+01     0.0340
# 7     338  GW190630_185205  GW190513_205428   8.180000e+01     0.0405
# 8     386  GW190706_222641  GW190719_215514   3.080000e+02     0.2850
# 9     422  GW190707_093326  GW190930_133541   9.140000e+02     0.0156
# 10    423  GW190708_232457         GW190412   1.300000e+02     0.0148
# 11    475  GW190720_000836  GW190728_064510   7.990000e+01     0.4830
# 12    484  GW190720_000836  GW190930_133541   5.100000e+01     0.0204
# 13    490  GW190727_060333  GW190424_180648   2.120000e+02     0.0135
# 14    512  GW190727_060333  GW190910_112807   6.210000e+01     0.0442
# 15    534  GW190728_064510  GW190930_133541   6.020000e+04     0.0251
# 16    538  GW190731_140936  GW190421_213856   6.210000e+02     0.0122
# 17    554  GW190731_140936  GW190803_022701   1.190000e+02     1.7600
# 18    559  GW190731_140936  GW190910_112807   1.610000e+02     0.0515
# 19    564  GW190803_022701  GW190910_112807   1.520000e+03     0.0567
# 20    633  GW190909_114149  GW190910_112807   4.400000e+01     5.2700
# 21    654  GW190915_235702  GW190719_215514   6.340000e+01     0.0298
# 22    675  GW190929_012149  GW190512_180714  4.430000e-315     0.0108
#
#     rlu_anupreeta   blu_fpp
# 0         0.59900      -inf
# 1         0.00000  0.006928
# 2         2.51000  0.005673
# 3         0.77400  0.009312
# 4         0.00719  0.008872
# 5         0.00000  0.005868
# 6         0.14600  0.009564
# 7         0.20200  0.007484
# 8         2.19000  0.003701
# 9         0.02420  0.001862
# 10        0.02000  0.005868
# 11        3.44000  0.007577
# 12        0.05230  0.009300
# 13        0.01410  0.004557
# 14        0.22700  0.008539
# 15        0.07550  0.000159
# 16        0.00707  0.002390
# 17        8.05000  0.006149
# 18        0.27200  0.005235
# 19        0.36300  0.001313
# 20       10.70000  0.009980
# 21        0.10700  0.008491
# 22        0.00000      -inf

# %% [markdown]
# # Find lensed pair candidates and compare to BLU results

# %%
ML_O3a_real['event1']=ML_O3a_real['img_0'].str.split('-').str[0]
ML_O3a_real['event2']=ML_O3a_real['img_1'].str.split('-').str[0]

# %%
o3a_merged_blu_ML_1 = pd.merge(ML_O3a_real, blu_haris_O3a_real, on=["event1", "event2"])
blu_haris_O3a_real_swap = blu_haris_O3a_real.rename(columns={'event1':'event2','event2':'event1'})
o3a_merged_blu_ML_2 = pd.merge(ML_O3a_real, blu_haris_O3a_real_swap, on=["event1", "event2"])

# %%
O3a_real_merged_blu_ML=pd.concat([o3a_merged_blu_ML_1,o3a_merged_blu_ML_2]).reset_index().drop(columns=['index'])
O3a_real_merged_blu_ML.Lensing=0
#O3a_real_merged_blu_ML=O3a_real_merged_blu_ML.dropna()

# %%
available_pairs=(pd.isna(O3a_real_merged_blu_ML['pe_skymaps_blu']).values==False)

# %%
O3a_real_merged_blu_ML=O3a_real_merged_blu_ML[available_pairs]

# %%
plt.figure(figsize=(20,5))
plt.subplot(131)
ml_stat = 'densnet_xgbsky_pe_mul_0'
blu_stat='blu'
plt.loglog(O3a_real_merged_blu_ML[ml_stat+'_fpp'],O3a_real_merged_blu_ML[blu_stat+'_fpp'],'.')
x=10**np.linspace(-5,0,30)
plt.loglog(x,x)
plt.xlabel('ML combined FPP')
plt.ylabel('BLU FPP')
plt.axvline(1e-2,ls='dashed',color='k')
plt.axhline(1e-2,ls='dashed',color='k')
plt.grid()

plt.subplot(132)
ml_stat = 'xgb_dense_QTS_0'
blu_stat='blu'
plt.loglog(O3a_real_merged_blu_ML[ml_stat+'_fpp'],O3a_real_merged_blu_ML[blu_stat+'_fpp'],'.')
x=10**np.linspace(-5,0,30)
plt.loglog(x,x)
plt.xlabel('ML QTs FPP')
plt.ylabel('BLU FPP')
plt.axvline(1e-2,ls='dashed',color='k')
plt.axhline(1e-2,ls='dashed',color='k')
plt.grid()

plt.subplot(133)
ml_stat = 'xgb_pred_pe_skymaps'
blu_stat='blu'
plt.loglog(O3a_real_merged_blu_ML[ml_stat+'_fpp'],O3a_real_merged_blu_ML[blu_stat+'_fpp'],'.')
x=10**np.linspace(-5,0,30)
plt.loglog(x,x)
plt.xlabel('ML sky FPP')
plt.ylabel('BLU FPP')
plt.axvline(1e-2,ls='dashed',color='k')
plt.axhline(1e-2,ls='dashed',color='k')
plt.grid()
plt.show()

# %%
ml_stat = 'densnet_xgbsky_pe_mul_0'
O3a_real_merged_blu_ML=O3a_real_merged_blu_ML.replace(-np.inf,1)

filter_ids_1=(O3a_real_merged_blu_ML[ml_stat+'_fpp']>1e-2) & (O3a_real_merged_blu_ML[blu_stat+'_fpp']>1e-2)
filter_ids_2=(O3a_real_merged_blu_ML[ml_stat+'_fpp']<1e-2) & (O3a_real_merged_blu_ML[blu_stat+'_fpp']>1e-2)
filter_ids_3=(O3a_real_merged_blu_ML[ml_stat+'_fpp']<1e-2) & (O3a_real_merged_blu_ML[blu_stat+'_fpp']<1e-2)
filter_ids_4=(O3a_real_merged_blu_ML[ml_stat+'_fpp']>1e-2) & (O3a_real_merged_blu_ML[blu_stat+'_fpp']<1e-2)
cols=['event1','event2','xgb_pred_pe_skymaps_fpp','xgb_dense_QTS_0_fpp','densnet_xgbsky_pe_mul_0_fpp','blu','blu_fpp','pe_skymaps_blu']

# %%
O3a_real_merged_blu_ML[filter_ids_2][cols].sort_values(by=['blu']).reset_index().drop(columns=['index'])
# Out:
#              event1           event2  xgb_pred_pe_skymaps_fpp  \
# 0   GW190519_153544  GW190930_133541                 0.099427
# 1   GW190512_180714  GW190521_074359                 0.092709
# 2          GW190521  GW190620_030421                 0.026925
# 3   GW190408_181802  GW190930_133541                 0.059654
# 4   GW190514_065416         GW190521                 0.085750
# 5   GW190527_092055  GW190728_064510                 0.012390
# 6   GW190527_092055  GW190720_000836                 0.071546
# 7   GW190503_185404  GW190602_175927                 0.023588
# 8   GW190413_052954  GW190706_222641                 0.027408
# 9          GW190521  GW190527_092055                 0.044757
# 10  GW190620_030421  GW190706_222641                 0.149800
# 11  GW190413_052954  GW190620_030421                 0.075311
# 12  GW190527_092055  GW190630_185205                 0.130853
# 13  GW190514_065416  GW190602_175927                 0.093892
# 14  GW190514_065416  GW190929_012149                 0.107175
# 15  GW190527_092055  GW190620_030421                 0.164474
# 16  GW190514_065416  GW190620_030421                 0.026925
# 17  GW190527_092055  GW190701_203306                 0.186034
#
#     xgb_dense_QTS_0_fpp  densnet_xgbsky_pe_mul_0_fpp            blu   blu_fpp  \
# 0              0.001228                     0.005283   0.000000e+00  1.000000
# 1              0.000400                     0.003486   0.000000e+00  1.000000
# 2              0.001284                     0.001841   0.000000e+00  1.000000
# 3              0.000938                     0.002443  1.630000e-299  0.304175
# 4              0.000290                     0.003147   2.170000e-65  0.226930
# 5              0.000351                     0.001811   7.090000e-53  0.217957
# 6              0.001721                     0.003854   5.510000e-52  0.217290
# 7              0.063390                     0.008274   7.910000e-40  0.206371
# 8              0.040323                     0.007202   1.990000e-28  0.193570
# 9              0.000681                     0.001845   9.240000e-27  0.191310
# 10             0.000452                     0.007429   1.020000e-02  0.093494
# 11             0.003213                     0.005800   1.410000e-01  0.065012
# 12             0.000739                     0.006882   3.220000e-01  0.055979
# 13             0.001892                     0.006015   6.890000e-01  0.048013
# 14             0.000395                     0.004502   1.010000e+00  0.043951
# 15             0.000060                     0.007752   1.950000e+00  0.037024
# 16             0.000728                     0.001838   1.490000e+01  0.016250
# 17             0.000355                     0.009928   1.540000e+01  0.016017
#
#     pe_skymaps_blu
# 0         1.406821
# 1         3.165975
# 2         1.903942
# 3         3.274625
# 4         1.996581
# 5         9.073790
# 6         2.012948
# 7         5.493652
# 8         4.873970
# 9         3.225272
# 10        0.998205
# 11        1.362368
# 12        0.826666
# 13        1.794051
# 14        1.324541
# 15        0.632957
# 16        1.890499
# 17        0.969896

# %%
filter_ids=(O3a_real_merged_blu_ML['xgb_dense_QTS_0_fpp']<1e-2) & (O3a_real_merged_blu_ML['xgb_pred_pe_skymaps_fpp']<1e-1)
O3a_real_merged_blu_ML_filtered = O3a_real_merged_blu_ML[filter_ids]
plt.figure(figsize=(20,5))
plt.subplot(131)
ml_stat = 'densnet_xgbsky_pe_mul_0'
blu_stat='blu'
plt.loglog(O3a_real_merged_blu_ML_filtered[ml_stat+'_fpp'],O3a_real_merged_blu_ML_filtered[blu_stat+'_fpp'],'.')
x=10**np.linspace(-5,0,30)
plt.loglog(x,x)
plt.xlabel('ML combined FPP')
plt.ylabel('BLU FPP')
plt.axvline(1e-2,ls='dashed',color='k')
plt.axhline(1e-2,ls='dashed',color='k')
plt.grid()

plt.subplot(132)
ml_stat = 'xgb_dense_QTS_0'
blu_stat='blu'
plt.loglog(O3a_real_merged_blu_ML_filtered[ml_stat+'_fpp'],O3a_real_merged_blu_ML_filtered[blu_stat+'_fpp'],'.')
x=10**np.linspace(-5,0,30)
plt.loglog(x,x)
plt.xlabel('ML QTs FPP')
plt.ylabel('BLU FPP')
plt.axvline(1e-2,ls='dashed',color='k')
plt.axhline(1e-2,ls='dashed',color='k')
plt.grid()

plt.subplot(133)
ml_stat = 'xgb_pred_pe_skymaps'
blu_stat='blu'
plt.loglog(O3a_real_merged_blu_ML_filtered[ml_stat+'_fpp'],O3a_real_merged_blu_ML_filtered[blu_stat+'_fpp'],'.')
x=10**np.linspace(-5,0,30)
plt.loglog(x,x)
plt.xlabel('ML sky FPP')
plt.ylabel('BLU FPP')
plt.axvline(1e-2,ls='dashed',color='k')
plt.axhline(1e-2,ls='dashed',color='k')
plt.grid()
plt.show()
