# %%
# !which python
# Out:
# /home/srashti.goyal/.conda/envs/igwn-py37-hanabi/bin/python

# %%
import lensid.utils.ml_utils as ml
# Out:
# 2021-11-05 22:36:55.188454: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2021-11-05 22:36:55.188515: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import pandas as pd
import numpy as np

# %%
import lensid.train_test.train_densenets_qts as dense_train

# %%
data_dir_old = '/home/srashti.goyal/alice_data_lensid/qts/train/'
data_dir_ml2p0 = '/home/srashti.goyal/lensid_runs/ML_2p0_AnalyticalPsd/data/qts/train/'

# %%
data_dir_ml1p0 = '/home/srashti.goyal/lensid_runs/ML_1p0_AnalyticalPsd/data/qts/train/'
data_dir_ml1p0_qmode2 = '/home/srashti.goyal/lensid_runs/ML_1p0_AnalyticalPsd_qmode_2/data/qts/train/'
data_dir_ml1p0_whitened = '/home/srashti.goyal/lensid_runs/ML_1p0_AnalyticalPsd_whitened/data/qts/train/'

# %%
mode = 'ml1p0' # old, 'ml1p0', 'ml2p0','ml1p0_qmode2','ml1p0_whiten'

# %%
lensed_df = '/home/srashti.goyal/lensid_runs/ML_2p0_AnalyticalPsd/data/dataframes/train/lensed.csv'

# %%
lensed_df_old = 'lensed_old.csv'

# %%
unlensed_df = '/home/srashti.goyal/lensid_runs/ML_2p0_AnalyticalPsd/data/dataframes/train/unlensed_half.csv'

# %%
size_lensed = 1400
size_unlensed = 1400
det = 'H1'
epochs = 20
lr = 0.003

# %%
odir = mode+'_lr_max_'+ 'lr_'+str(lr)+'_epochs_'+str(epochs) +'_sizel_'+str(size_lensed)+'_sizeul_'+str(size_unlensed)+'_'

# %%
import sys

orig_stdout = sys.stdout
f = open(odir+det+'.txt', 'w')
sys.stdout = f

# %%
# ml2p0
if mode == 'ml2p0':
    dense_train._main(
        odir,
        data_dir_ml2p0,
        lensed_df,
        unlensed_df,
        size_lensed,
        size_unlensed,
        det,
        epochs,
        lr,
        1,
    )

# %%
# ml1p0
if mode == 'ml1p0':

    dense_train._main(
        odir,
        data_dir_ml1p0,
        lensed_df,
        unlensed_df,
        size_lensed,
        size_unlensed,
        det,
        epochs,
        lr,
        0,
    )
# ml1p0_qmode2
if mode == 'ml1p0_qmode2':

    dense_train._main(
        odir,
        data_dir_ml1p0_qmode2,
        lensed_df,
        unlensed_df,
        size_lensed,
        size_unlensed,
        det,
        epochs,
        lr,
        0,
    )
# ml1p0
if mode == 'ml1p0_whiten':

    dense_train._main(
        odir,
        data_dir_ml1p0_whitened,
        lensed_df,
        unlensed_df,
        size_lensed,
        size_unlensed,
        det,
        epochs,
        lr,
        1,
    )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /local/srashti.goyal/ipykernel_114525/1881875630.py in <module>
#      12         epochs,
#      13         lr,
# ---> 14         0,
#      15     )
#      16 # ml1p0_qmode2
#
# ~/.conda/envs/igwn-py37-hanabi/lib/python3.7/site-packages/lensid/train_test/train_densenets_qts.py in _main(odir, data_dir, lensed_df, unlensed_df, size_lensed, size_unlensed, det, epochs, lr, whitened)
#     102
#     103     X, y, missing_ids, df_train = ml.generate_resize_densenet_fm(df_train).DenseNet_input_matrix(
# --> 104         det=det, data_mode_dense="current", data_dir=data_dir, phenom=1, whitened =whitened)
#     105
#     106     dense_model_trained = ml.train_densenet(
#
# ~/.conda/envs/igwn-py37-hanabi/lib/python3.7/site-packages/lensid/utils/ml_utils.py in DenseNet_input_matrix(self, det, data_mode_dense, data_dir, phenom, whitened)
# ...

# %%
#old
if mode == 'old':

    dense_train._main(
        odir,
        data_dir_old,
        lensed_df_old,
        unlensed_df,
        size_lensed,
        size_unlensed,
        det,
        epochs,
        lr,
        0,
    )

# %%
print(odir)
sys.stdout = orig_stdout
f.close()

# %% [raw]
# lr_0.01_epochs_15_sizel_1400_sizeul_1400_H1.h5
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 1.5368709120000003e-05.
# 70/70 [==============================] - 12s 166ms/step - loss: 1.8595 - accuracy: 1.0000 - val_loss: 2.4511 - val_accuracy: 0.7929
# Time Taken:  211.7424397468567
#
# lr_0.005_epochs_15_sizel_1400_sizeul_1400_H1.h5
#
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 1.6710886400000004e-05.
# 70/70 [==============================] - 11s 157ms/step - loss: 1.1190 - accuracy: 1.0000 - val_loss: 1.7500 - val_accuracy: 0.7768
# Epoch 15/15
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 1.5368709120000003e-05.
# 70/70 [==============================] - 11s 161ms/step - loss: 1.0804 - accuracy: 1.0000 - val_loss: 1.7420 - val_accuracy: 0.7732
#
# lr_0.01_epochs_20_sizel_1400_sizeul_1400_
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 1.1759218604441602e-05.
# 70/70 [==============================] - 12s 171ms/step - loss: 1.5462 - accuracy: 0.9982 - val_loss: 2.1313 - val_accuracy: 0.8071
# Time Taken:  262.1468725204468
#
# lr_max =*8
#
# 70/70 [==============================] - 11s 163ms/step - loss: 0.2222 - accuracy: 1.0000 - val_loss: 0.6791 - val_accuracy: 0.8768
# Time Taken:  265.507999420166
# lr_0.003_epochs_20_sizel_1400_sizeul_1400_

# %% [raw]
# old:-
#
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 1.1759218604441602e-05.
# 70/70 [==============================] - 11s 160ms/step - loss: 1.5084 - accuracy: 0.9995 - val_loss: 2.1076 - val_accuracy: 0.8339
# Time Taken:  262.6394250392914
#
# 70/70 [==============================] - 11s 154ms/step - loss: 0.9404 - accuracy: 1.0000 - val_loss: 1.4376 - val_accuracy: 0.8714
# Time Taken:  251.88139700889587
# lr_0.005_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 159ms/step - loss: 0.6245 - accuracy: 1.0000 - val_loss: 1.0477 - val_accuracy: 0.8839
# Time Taken:  255.4203028678894
# lr_0.003_epochs_20_sizel_1400_sizeul_1400_

# %% [raw]
# # ml1p0
#
# det H1
#
#
# 70/70 [==============================] - 11s 152ms/step - loss: 0.1518 - accuracy: 1.0000 - val_loss: 0.6288 - val_accuracy: 0.8946
# Time Taken:  224.25406908988953
# optimising/ml1p0_lr_max_lr_0.01_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 10s 149ms/step - loss: 0.1886 - accuracy: 1.0000 - val_loss: 0.5739 - val_accuracy: 0.9071
# Time Taken:  225.53520345687866
# optimising/ml1p0_lr_max_lr_0.007_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 157ms/step - loss: 0.1918 - accuracy: 1.0000 - val_loss: 0.7295 - val_accuracy: 0.8911
# Time Taken:  225.30372071266174
# optimising/ml1p0_lr_max_lr_0.005_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 9s 128ms/step - loss: 0.1998 - accuracy: 1.0000 - val_loss: 0.6159 - val_accuracy: 0.9125
# Time Taken:  224.57079529762268
# optimising/ml1p0_lr_max_lr_0.003_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 158ms/step - loss: 0.1251 - accuracy: 1.0000 - val_loss: 0.5711 - val_accuracy: 0.9125
# Time Taken:  230.42417764663696
# optimising/ml1p0_lr_max_lr_0.001_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 157ms/step - loss: 0.0819 - accuracy: 1.0000 - val_loss: 0.5334 - val_accuracy: 0.9125
# Time Taken:  259.05255365371704
# optimising/ml1p0_lr_max_lr_0.0005_epochs_20_sizel_1400_sizeul_1400_
#
#
# 70/70 [==============================] - 11s 150ms/step - loss: 0.1337 - accuracy: 0.9997 - val_loss: 0.8050 - val_accuracy: 0.8804
# Time Taken:  225.77122521400452
# optimising/ml1p0_lr_max_lr_0.001_epochs_20_sizel_1400_sizeul_1400_
#
# det L1
#
# 70/70 [==============================] - 10s 149ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.6120 - val_accuracy: 0.8875
# Time Taken:  244.9924840927124
# optimising/ml1p0_lr_max_lr_0.0001_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 157ms/step - loss: 0.0848 - accuracy: 1.0000 - val_loss: 0.7099 - val_accuracy: 0.8911
# Time Taken:  229.0079185962677
# optimising/ml1p0_lr_max_lr_0.0005_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 10s 149ms/step - loss: 0.2058 - accuracy: 1.0000 - val_loss: 0.7037 - val_accuracy: 0.8768
# Time Taken:  226.72622632980347
# optimising/ml1p0_lr_max_lr_0.005_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 10s 149ms/step - loss: 0.1377 - accuracy: 1.0000 - val_loss: 0.6175 - val_accuracy: 0.8714
# Time Taken:  237.42132258415222
# optimising/ml2p0_lr_max_lr_0.001_epochs_20_sizel_1400_sizeul_1400_
#
#
# det V1
# 70/70 [==============================] - 11s 153ms/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.8754 - val_accuracy: 0.8518
# Time Taken:  231.6087052822113
# optimising/ml1p0_lr_max_lr_0.0001_epochs_20_sizel_1400_sizeul_1400_

# %% [raw]
# # ml2p0
#
# 70/70 [==============================] - 8s 114ms/step - loss: 0.0848 - accuracy: 1.0000 - val_loss: 0.6142 - val_accuracy: 0.8643
# Time Taken:  227.76686429977417
# optimising/ml2p0_lr_max_lr_0.0005_epochs_20_sizel_1400_sizeul_1400_
#
#
# 70/70 [==============================] - 11s 155ms/step - loss: 0.1357 - accuracy: 1.0000 - val_loss: 0.6080 - val_accuracy: 0.8679
# Time Taken:  231.6870994567871
# optimising/ml2p0_lr_max_lr_0.001_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 10s 150ms/step - loss: 0.2169 - accuracy: 1.0000 - val_loss: 0.8094 - val_accuracy: 0.8464
#
#
# 70/70 [==============================] - 11s 153ms/step - loss: 0.2181 - accuracy: 1.0000 - val_loss: 0.7145 - val_accuracy: 0.8804
# Time Taken:  229.71788144111633
# optimising/ml2p0_lr_max_lr_0.005_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 151ms/step - loss: 0.2097 - accuracy: 1.0000 - val_loss: 0.6505 - val_accuracy: 0.8804
# Time Taken:  222.84431982040405
#
# 70/70 [==============================] - 9s 134ms/step - loss: 0.1845 - accuracy: 1.0000 - val_loss: 0.5941 - val_accuracy: 0.8821
# Time Taken:  226.91137719154358
# optimising/ml2p0_lr_max_lr_0.01_epochs_20_sizel_1400_sizeul_1400_

# %% [raw]
# #ml1p0_qmode2
#
# 70/70 [==============================] - 9s 124ms/step - loss: 0.0846 - accuracy: 1.0000 - val_loss: 0.6946 - val_accuracy: 0.8554
# Time Taken:  228.7389521598816
# optimising/ml1p0_qmode2_lr_max_lr_0.0005_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 9s 134ms/step - loss: 0.1292 - accuracy: 1.0000 - val_loss: 0.5670 - val_accuracy: 0.8982
# Time Taken:  233.91286277770996
# optimising/ml1p0_qmode2_lr_max_lr_0.001_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 12s 165ms/step - loss: 0.2217 - accuracy: 1.0000 - val_loss: 0.8288 - val_accuracy: 0.8500
# Time Taken:  232.26996326446533
# optimising/ml1p0_qmode2_lr_max_lr_0.003_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 152ms/step - loss: 0.2344 - accuracy: 1.0000 - val_loss: 0.7244 - val_accuracy: 0.8857
# Time Taken:  234.60910058021545
# optimising/ml1p0_qmode2_lr_max_lr_0.005_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 161ms/step - loss: 0.2124 - accuracy: 1.0000 - val_loss: 0.6867 - val_accuracy: 0.8732
#
# 70/70 [==============================] - 10s 149ms/step - loss: 0.1644 - accuracy: 1.0000 - val_loss: 0.6544 - val_accuracy: 0.8821
# Time Taken:  230.31459760665894
# optimising/ml1p0_qmode2_lr_max_lr_0.01_epochs_20_sizel_1400_sizeul_1400_

# %% [raw]
# #ml1p0_whiten
# 70/70 [==============================] - 11s 152ms/step - loss: 0.0845 - accuracy: 1.0000 - val_loss: 0.4941 - val_accuracy: 0.9125
# Time Taken:  233.27001237869263
# optimising/ml1p0_whiten_lr_max_lr_0.0005_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 13s 184ms/step - loss: 0.1328 - accuracy: 1.0000 - val_loss: 0.6660 - val_accuracy: 0.8875
# Time Taken:  240.95756268501282
# optimising/ml1p0_whiten_lr_max_lr_0.001_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 157ms/step - loss: 0.2098 - accuracy: 1.0000 - val_loss: 0.7255 - val_accuracy: 0.8929
# Time Taken:  227.46266341209412
# optimising/ml1p0_whiten_lr_max_lr_0.003_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 12s 168ms/step - loss: 0.2111 - accuracy: 1.0000 - val_loss: 0.6872 - val_accuracy: 0.8946
# Time Taken:  242.64802837371826
# optimising/ml1p0_whiten_lr_max_lr_0.005_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 156ms/step - loss: 0.1556 - accuracy: 1.0000 - val_loss: 0.6590 - val_accuracy: 0.8893
# Time Taken:  246.6698133945465
# optimising/ml1p0_whiten_lr_max_lr_0.007_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 13s 179ms/step - loss: 0.1317 - accuracy: 1.0000 - val_loss: 0.5921 - val_accuracy: 0.8804
# Time Taken:  246.64433455467224
# optimising/ml1p0_whiten_lr_max_lr_0.01_epochs_20_sizel_1400_sizeul_1400_

# %% [raw]
# #old
# 70/70 [==============================] - 12s 178ms/step - loss: 0.0825 - accuracy: 1.0000 - val_loss: 0.5157 - val_accuracy: 0.9161
# Time Taken:  250.26928305625916
# optimising/old_lr_max_lr_0.0005_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 12s 175ms/step - loss: 0.1330 - accuracy: 1.0000 - val_loss: 0.5129 - val_accuracy: 0.9107
# Time Taken:  249.88600873947144
# optimising/old_lr_max_lr_0.001_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 13s 181ms/step - loss: 0.2039 - accuracy: 1.0000 - val_loss: 0.7547 - val_accuracy: 0.8839
# Time Taken:  252.49643230438232
# optimising/old_lr_max_lr_0.003_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 162ms/step - loss: 0.2209 - accuracy: 1.0000 - val_loss: 0.6855 - val_accuracy: 0.8857
# Time Taken:  247.84131979942322
# optimising/old_lr_max_lr_0.005_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 157ms/step - loss: 0.1723 - accuracy: 1.0000 - val_loss: 0.6550 - val_accuracy: 0.8982
# Time Taken:  236.36264991760254
# optimising/old_lr_max_lr_0.007_epochs_20_sizel_1400_sizeul_1400_
#
# 70/70 [==============================] - 11s 156ms/step - loss: 0.1608 - accuracy: 1.0000 - val_loss: 0.5798 - val_accuracy: 0.9018
# Time Taken:  236.58890748023987
# optimising/old_lr_max_lr_0.01_epochs_20_sizel_1400_sizeul_1400_

# %%
#model = ml.load_model('optimising/ml1p0_lr_max_lr_0.005_epochs_20_sizel_1400_sizeul_1400_V1.h5')

# %%
fname = 'optimising/ml1p0_lr_max_lr_0.005_epochs_20_sizel_1400_sizeul_1400_V1.txt'

with open(fname) as f:
    contents = f.readlines()
    print(contents[-3][-40:])

    print(contents[-1])
# Out:
# val_loss: 0.7594 - val_accuracy: 0.8786
#
# optimising/ml1p0_lr_max_lr_0.005_epochs_20_sizel_1400_sizeul_1400_

# %%
modes = ['ml1p0'  , 'ml1p0_whiten','ml2p0','ml1p0_qmode2','old']
lrs = [0.0001,0.0005, 0.001, 0.005, 0.01, 0.015]

epochs = 20
size_lensed = 1400
size_unlensed = 1400
for mode in modes:
    print('****',mode,'*****')
    for det in ['L1','V1']:
        print('\t****',det,'*****')

        for lr in lrs:
            odir = 'optimising/'+mode+'_lr_max_'+ 'lr_'+str(lr)+'_epochs_'+str(epochs) +'_sizel_'+str(size_lensed)+'_sizeul_'+str(size_unlensed)+'_'
            fname=odir+det+'.txt'
            with open(fname) as f:
                contents = f.readlines()
                print(lr , contents[-3][-40:])
             #   print('**',contents[-1])
#                print('----\n----')
# Out:
# **** ml1p0 *****
# 	**** L1 *****
# 0.0001 val_loss: 0.6120 - val_accuracy: 0.8875
#
# 0.0005 val_loss: 0.7099 - val_accuracy: 0.8911
#
# 0.001 val_loss: 0.8050 - val_accuracy: 0.8804
#
# 0.005 val_loss: 0.7037 - val_accuracy: 0.8768
#
# 0.01 val_loss: 0.4850 - val_accuracy: 0.9268
#
# 0.015 val_loss: 0.6104 - val_accuracy: 0.8839
#
# 	**** V1 *****
# 0.0001 val_loss: 0.8754 - val_accuracy: 0.8518
#
# 0.0005 val_loss: 0.7452 - val_accuracy: 0.8929
#
# 0.001 val_loss: 0.7838 - val_accuracy: 0.8804
#
# 0.005 val_loss: 0.7594 - val_accuracy: 0.8786
#
# 0.01 val_loss: 0.5949 - val_accuracy: 0.8946
#
# 0.015 val_loss: 0.4662 - val_accuracy: 0.9089
#
# **** ml1p0_whiten *****
# 	**** L1 *****
# 0.0001 val_loss: 0.8216 - val_accuracy: 0.8661
#
# 0.0005 val_loss: 0.6265 - val_accuracy: 0.8875
#
# 0.001 val_loss: 0.7120 - val_accuracy: 0.8911
#
# 0.005 val_loss: 0.6335 - val_accuracy: 0.9107
#
# 0.01 val_loss: 0.5898 - val_accuracy: 0.9125
#
# 0.015 val_loss: 0.5406 - val_accuracy: 0.8929
#
# ...

# %%
modes = ['ml1p0'  , 'ml1p0_whiten','ml2p0','ml1p0_qmode2','old']
lrs = [0.0005, 0.001, 0.003,0.005, 0.007, 0.01]

epochs = 20
size_lensed = 1400
size_unlensed = 1400
for mode in modes:
    print('****',mode,'*****')
    for det in ['H1']:
        print('\t****',det,'*****')

        for lr in lrs:
            odir = 'optimising/'+mode+'_lr_max_'+ 'lr_'+str(lr)+'_epochs_'+str(epochs) +'_sizel_'+str(size_lensed)+'_sizeul_'+str(size_unlensed)+'_'
            fname=odir+det+'.txt'
            with open(fname) as f:
                contents = f.readlines()
                print(lr , contents[-3][-40:])
             #   print('**',contents[-1])
#                print('----\n----')
# Out:
# **** ml1p0 *****
# 	**** H1 *****
# 0.0005 val_loss: 0.5334 - val_accuracy: 0.9125
#
# 0.001 val_loss: 0.5711 - val_accuracy: 0.9125
#
# 0.003 val_loss: 0.6159 - val_accuracy: 0.9125
#
# 0.005 val_loss: 0.7295 - val_accuracy: 0.8911
#
# 0.007 val_loss: 0.5739 - val_accuracy: 0.9071
#
# 0.01 val_loss: 0.6288 - val_accuracy: 0.8946
#
# **** ml1p0_whiten *****
# 	**** H1 *****
# 0.0005 val_loss: 0.4941 - val_accuracy: 0.9125
#
# 0.001 val_loss: 0.6660 - val_accuracy: 0.8875
#
# 0.003 val_loss: 0.7255 - val_accuracy: 0.8929
#
# 0.005 val_loss: 0.6872 - val_accuracy: 0.8946
#
# 0.007 val_loss: 0.6590 - val_accuracy: 0.8893
#
# 0.01 val_loss: 0.5921 - val_accuracy: 0.8804
#
# **** ml2p0 *****
# 	**** H1 *****
# 0.0005 val_loss: 0.6142 - val_accuracy: 0.8643
#
# 0.001 val_loss: 0.6080 - val_accuracy: 0.8679
#
# 0.003 val_loss: 0.8094 - val_accuracy: 0.8464
#
# 0.005 val_loss: 0.7145 - val_accuracy: 0.8804
#
# 0.007 val_loss: 0.6505 - val_accuracy: 0.8804
#
# ...
